# %%
estimates_vs_actuals_task_to_story = """
select	
	task.Name as TaskName,
	project.Name as ProjectName,
	story.Name as StoryName,
	user.DisplayName,
	user.EmailAddress,
	task.Actuals as TaskActuals_hrs,
	task.Estimate as TaskEstimate_hrs,
	story.PlanEstimate as StoryEstimate_pts
from
	task
left join
	story
on
	task.StoryId = story.Id
left join
	project
on
	task.ProjectId = project.Id
left join
	user
on
	task.OwnerId = user.Id
where
	task.State = 'Completed'
"""

estimates_vs_actuals_story_to_function = """
select	
	function.Name as FunctionName,
	project.Name AS ProjectName,
	story.Name AS StoryName,
	CAST(function.PreliminaryEstimate as int) as FunctionPrelimEstimate_pts,
	SUM(task.Actuals) as StoryActuals_hrs,
    SUM(task.Estimate) as StoryEstimateByTask_hrs,
    story.PlanEstimate as StoryEstimate_pts
from
	task
left join
	story
on
	task.StoryId = story.Id
left join
	project
on
	task.ProjectId = project.Id
left join
	function
on
	story.FunctionId = function.Id
where
	task.State = 'Completed'
and
	function.Name is not null
and
    function.ActualEndDate is not null
and
    story.PlanEstimate > 0
group by
	function.Name,
	project.Name,
	function.PreliminaryEstimate,
	story.Name
having
    sum(task.Actuals) > 0 and sum(task.Estimate) > 0
"""

insprint_defects = """
select
	project.Name  as ProjectName,
	iteration.Name  as IterationName,
	DATETIME(iteration.StartDate) AS IterationStartDate,
	DATETIME(iteration.EndDate) as IterationEndDate,
	defect.Name  as DefectName,
	case when 
	defect.Severity = 'Major Problem' then 2 
	else case when defect.severity = 'Minor Problem' then 1
	else case when defect.Name is not null then 0
	end end end as DefectSeverity
from
	iteration
left join
	defect
on
	defect.IterationId = iteration.Id
inner join
	project
on
	iteration.ProjectId = project.Id
where
    iteration.EndDate < date('now')
"""

# %%
import sqlalchemy
import pandas as pd


def connect_to_data():
    engine = sqlalchemy.create_engine(
        'sqlite:///' + r'C:\Users\Tyler Hughes\Documents\Kingsmen Repositories\bannerman\bannerman\bannerman.db'
    )
    return engine.connect()

db = connect_to_data()

task_to_story_df = pd.read_sql_query(
        sql=estimates_vs_actuals_task_to_story,
        con=db
    )

story_to_function_df = pd.read_sql_query(
        sql=estimates_vs_actuals_story_to_function,
        con=db
    )

defect_df = pd.read_sql_query(
        sql=insprint_defects,
        con=db
    )

# %%
tts_df = task_to_story_df.copy().groupby(
    ['ProjectName', 'StoryName']
).sum().reset_index().drop(['StoryEstimate_pts'], axis=1)

tts_user_df = task_to_story_df.copy().groupby(
    ['ProjectName', 'DisplayName', 'StoryName', 'EmailAddress']
).sum().reset_index().drop(['StoryEstimate_pts'], axis=1)

join_table = task_to_story_df[task_to_story_df['StoryEstimate_pts'] > 0].copy().drop(
        ['TaskName', 'DisplayName', 'EmailAddress', 'TaskActuals_hrs', 'TaskEstimate_hrs'],
        axis=1
    ).drop_duplicates().reset_index()

tts_df = tts_df.merge(join_table, on=['ProjectName', 'StoryName'])

tts_df['ActualVsEstimateDiff'] = tts_df['TaskActuals_hrs'] - tts_df['TaskEstimate_hrs']
tts_df['EstimatedHoursPerPoint'] = tts_df['TaskEstimate_hrs']/tts_df['StoryEstimate_pts']
tts_df['ActualHoursPerPoint'] = tts_df['TaskActuals_hrs']/tts_df['StoryEstimate_pts']

# %%
tts_report_full = tts_df.copy()

tts_report_full.dropna(inplace=True)

tts_report_summary = tts_report_full.copy()[
    (tts_report_full['EstimatedHoursPerPoint'] > 0) & (tts_report_full['ActualHoursPerPoint'] > 0)
].drop(
    ['TaskActuals_hrs','TaskEstimate_hrs', 'StoryEstimate_pts'],
    axis=1
).groupby(['ProjectName']).mean().reset_index().drop('index', axis=1)

tts_report_summary
# Out:
#               ProjectName  ActualVsEstimateDiff  EstimatedHoursPerPoint  \
# 0    Compliance Workbench             -1.166364                4.838909
# 1  Market Data Connection             -2.213956                5.665125
# 2                  Seurat             -1.022293                6.057962
# 3                 TSquare              0.068000                5.399067
#
#    ActualHoursPerPoint
# 0             4.415909
# 1             4.787891
# 2             5.376327
# 3             5.605633

# %%
stf_df = story_to_function_df.copy().groupby(['ProjectName', 'FunctionName']).sum().reset_index().drop(
    ['FunctionPrelimEstimate_pts'], axis=1)

join_table = story_to_function_df[story_to_function_df['FunctionPrelimEstimate_pts'] > 0].copy()
join_table = join_table.drop(
        ['StoryName', 'StoryActuals_hrs', 'StoryEstimateByTask_hrs', 'StoryEstimate_pts'],
        axis=1
    ).drop_duplicates().reset_index().drop('index', axis=1)

stf_df = stf_df.merge(join_table, on=['ProjectName', 'FunctionName'])

stf_df['StoryFunctionEstimateDiff'] = stf_df['StoryEstimate_pts'] - stf_df['FunctionPrelimEstimate_pts']
stf_df['ActualVsEstimateTasksTotal'] = stf_df['StoryActuals_hrs'] - stf_df['StoryEstimateByTask_hrs']
stf_df['TaskActualHoursPerStoryEstimate'] = stf_df['StoryActuals_hrs']/stf_df['StoryEstimate_pts']
stf_df['TaskEstimatedHoursPerStoryEstimate'] = stf_df['StoryEstimateByTask_hrs']/stf_df['StoryEstimate_pts']
stf_df['TaskActualHoursPerFunctionPrelimEstimate'] = stf_df['StoryActuals_hrs']/stf_df['FunctionPrelimEstimate_pts']
stf_df['TaskEstimatedHoursPerFunctionPrelimEstimate'] = stf_df['StoryEstimateByTask_hrs']/stf_df['FunctionPrelimEstimate_pts']

stf_report = stf_df.copy().dropna().drop(['StoryActuals_hrs', 'StoryEstimateByTask_hrs', 'StoryEstimate_pts',
                                         'FunctionPrelimEstimate_pts'], axis=1).groupby(['ProjectName']).mean().reset_index()
stf_df
# Out:
#               ProjectName                              FunctionName  \
# 0    Compliance Workbench                    Application Appearance
# 1    Compliance Workbench                Application Infrastructure
# 2    Compliance Workbench                  Configuration Item Admin
# 3    Compliance Workbench                       Control Point Admin
# 4    Compliance Workbench                    Control Room Dashboard
# 5    Compliance Workbench         Control Room User Experience - R4
# 6    Compliance Workbench                           Dashboard Admin
# 7    Compliance Workbench                             Email Service
# 8    Compliance Workbench                           Email Templates
# 9    Compliance Workbench                             Event Service
# 10   Compliance Workbench           FrakWorx Dashboard Upgrade - R4
# 11   Compliance Workbench                            List Employees
# 12   Compliance Workbench                            Manage Actions
# 13   Compliance Workbench                    Manage Attestations R1
# 14   Compliance Workbench                    Manage Attestations R2
# 15   Compliance Workbench                      Manage Audit History
# 16   Compliance Workbench                Manage Company Association
# 17   Compliance Workbench                               Manage Deal
# 18   Compliance Workbench                          Manage Deal Team
# 19   Compliance Workbench                         Manage Encryption
# 20   Compliance Workbench                        Manage Event Types
# 21   Compliance Workbench                           Manage LCM Data
# 22   Compliance Workbench                       Manage Loan IQ Data
# 23   Compliance Workbench                      Manage Notifications
# 24   Compliance Workbench                          Manage Rule Sets
# 25   Compliance Workbench                              Manage Rules
# 26   Compliance Workbench                          Manage Situation
# 27   Compliance Workbench                           Manage TDM Data
# 28   Compliance Workbench                    Notification Templates
# 29   Compliance Workbench                  PIP User Experience - R4
# ..                    ...                                       ...
# 139                Seurat      Filter and search Graphlet instances
# 140                Seurat                               Import data
# 141                Seurat                   Import data version 2.1
# 142                Seurat                             LOB Dashboard
# 143                Seurat                   Launch instance reports
# 144                Seurat                             MVP Hardening
# 145                Seurat                          Manage Graphlets
# 146                Seurat              Manage Graphlets version 2.1
# 147                Seurat                 Manage Vendor Information
# 148                Seurat                 Manage attribute metadata
# 149                Seurat                       Manage data mapping
# 150                Seurat                    Manage entity metadata
# 151                Seurat                          Manage instances
# 152                Seurat              Manage instances version 2.1
# 153                Seurat                      Manage microservices
# 154                Seurat              Manage relationship metadata
# 155                Seurat  Manage relationship metadata version 2.1
# 156                Seurat             Platform upgrades version 2.2
# 157                Seurat                         Project Dashboard
# 158                Seurat                View Graphlet Configurator
# 159                Seurat                View implemented Graphlets
# 160               TSquare                             Cost Measures
# 161               TSquare                           Data structures
# 162               TSquare                                 Load data
# 163               TSquare                Manage Configuration Items
# 164               TSquare                     Manage Control Points
# 165               TSquare              Manage One Dimensional Goals
# 166               TSquare                              Manage Roles
# 167               TSquare                              Manage Users
# 168               TSquare                                  Security
#
#      StoryActuals_hrs  StoryEstimateByTask_hrs  StoryEstimate_pts  \
# 0               15.00                     16.0                3.0
# 1               18.00                     25.0                5.0
# 2               12.00                     20.0                4.0
# 3               12.00                     20.0                4.0
# 4                6.00                      6.0                1.0
# 5              123.00                    139.0               28.0
# 6               19.00                     20.0                4.0
# 7               46.00                     46.0               10.0
# 8               28.00                     26.0               12.0
# 9               16.00                     23.0                5.0
# 10              84.00                     84.0               15.0
# 11              28.00                     28.0                5.0
# 12              26.00                     26.0                5.0
# 13              21.00                     18.0                3.0
# 14              30.00                     32.0                6.0
# 15               9.00                     11.0                3.0
# 16              30.00                     32.0                9.0
# 17              92.00                    124.0               29.0
# 18              33.00                     42.0                8.0
# 19              30.00                     30.0                6.0
# 20               5.00                      8.0                2.0
# 21             210.00                    215.0               37.5
# 22              28.00                     28.0                5.0
# 23              51.00                     53.0               12.0
# 24              26.00                     27.0                6.0
# 25              24.00                     24.0                5.0
# 26              85.00                    100.0               25.0
# 27              86.00                     86.0               18.0
# 28              22.00                     23.0                9.0
# 29             217.00                    230.0               45.5
# ..                ...                      ...                ...
# 139             71.00                     79.0               11.0
# 140            100.00                     88.0               11.0
# 141             48.50                     79.0               13.0
# 142             42.50                     57.0               10.5
# 143             14.00                     20.0                3.0
# 144             68.00                     66.0                9.0
# 145            156.00                    160.0               29.5
# 146             17.00                     17.0                3.0
# 147              6.00                     19.0                4.0
# 148             47.00                     54.0                8.0
# 149            112.75                    132.0               23.0
# 150             74.00                     86.0               13.0
# 151             78.00                     84.0               12.0
# 152             62.00                     58.0                9.0
# 153             32.50                     34.0                5.0
# 154             77.00                     74.0               11.0
# 155             44.00                     42.0                7.0
# 156             35.00                     34.0                6.0
# 157             10.00                     12.0                2.0
# 158            100.50                     93.0               16.5
# 159             66.50                     91.0               13.5
# 160              5.00                      5.0                0.5
# 161              7.50                     13.0               10.0
# 162            171.00                    175.5               54.0
# 163              6.00                      6.0                2.0
# 164              4.00                      4.0                2.0
# 165             15.00                     13.0                6.0
# 166              6.00                      6.0                2.0
# 167             21.00                     17.0                4.0
# 168             26.50                     28.0               10.0
#
#      FunctionPrelimEstimate_pts  StoryFunctionEstimateDiff  \
# 0                           5.0                       -2.0
# 1                          10.0                       -5.0
# 2                           5.0                       -1.0
# 3                           5.0                       -1.0
# 4                          10.0                       -9.0
# 5                          30.0                       -2.0
# 6                           5.0                       -1.0
# 7                          10.0                        0.0
# 8                          10.0                        2.0
# 9                           5.0                        0.0
# 10                         20.0                       -5.0
# 11                          5.0                        0.0
# 12                          5.0                        0.0
# 13                          5.0                       -2.0
# 14                          5.0                        1.0
# 15                          5.0                       -2.0
# 16                         10.0                       -1.0
# 17                         20.0                        9.0
# 18                          5.0                        3.0
# 19                          5.0                        1.0
# 20                          5.0                       -3.0
# 21                         30.0                        7.5
# 22                          5.0                        0.0
# 23                         10.0                        2.0
# 24                          5.0                        1.0
# 25                          5.0                        0.0
# 26                         20.0                        5.0
# 27                         20.0                       -2.0
# 28                         10.0                       -1.0
# 29                         30.0                       15.5
# ..                          ...                        ...
# 139                        20.0                       -9.0
# 140                        20.0                       -9.0
# 141                        20.0                       -7.0
# 142                        10.0                        0.5
# 143                        10.0                       -7.0
# 144                         5.0                        4.0
# 145                        30.0                       -0.5
# 146                        30.0                      -27.0
# 147                         5.0                       -1.0
# 148                        10.0                       -2.0
# 149                        20.0                        3.0
# 150                        10.0                        3.0
# 151                        30.0                      -18.0
# 152                        30.0                      -21.0
# 153                        30.0                      -25.0
# 154                        10.0                        1.0
# 155                         5.0                        2.0
# 156                        10.0                       -4.0
# 157                        10.0                       -8.0
# 158                        10.0                        6.5
# 159                        20.0                       -6.5
# 160                        10.0                       -9.5
# 161                        10.0                        0.0
# 162                        30.0                       24.0
# 163                         5.0                       -3.0
# 164                         5.0                       -3.0
# 165                        10.0                       -4.0
# 166                         5.0                       -3.0
# 167                         5.0                       -1.0
# 168                        10.0                        0.0
#
#      ActualVsEstimateTasksTotal  TaskActualHoursPerStoryEstimate  \
# 0                         -1.00                         5.000000
# 1                         -7.00                         3.600000
# 2                         -8.00                         3.000000
# 3                         -8.00                         3.000000
# 4                          0.00                         6.000000
# 5                        -16.00                         4.392857
# 6                         -1.00                         4.750000
# 7                          0.00                         4.600000
# 8                          2.00                         2.333333
# 9                         -7.00                         3.200000
# 10                         0.00                         5.600000
# 11                         0.00                         5.600000
# 12                         0.00                         5.200000
# 13                         3.00                         7.000000
# 14                        -2.00                         5.000000
# 15                        -2.00                         3.000000
# 16                        -2.00                         3.333333
# 17                       -32.00                         3.172414
# 18                        -9.00                         4.125000
# 19                         0.00                         5.000000
# 20                        -3.00                         2.500000
# 21                        -5.00                         5.600000
# 22                         0.00                         5.600000
# 23                        -2.00                         4.250000
# 24                        -1.00                         4.333333
# 25                         0.00                         4.800000
# 26                       -15.00                         3.400000
# 27                         0.00                         4.777778
# 28                        -1.00                         2.444444
# 29                       -13.00                         4.769231
# ..                          ...                              ...
# 139                       -8.00                         6.454545
# 140                       12.00                         9.090909
# 141                      -30.50                         3.730769
# 142                      -14.50                         4.047619
# 143                       -6.00                         4.666667
# 144                        2.00                         7.555556
# 145                       -4.00                         5.288136
# 146                        0.00                         5.666667
# 147                      -13.00                         1.500000
# 148                       -7.00                         5.875000
# 149                      -19.25                         4.902174
# 150                      -12.00                         5.692308
# 151                       -6.00                         6.500000
# 152                        4.00                         6.888889
# 153                       -1.50                         6.500000
# 154                        3.00                         7.000000
# 155                        2.00                         6.285714
# 156                        1.00                         5.833333
# 157                       -2.00                         5.000000
# 158                        7.50                         6.090909
# 159                      -24.50                         4.925926
# 160                        0.00                        10.000000
# 161                       -5.50                         0.750000
# 162                       -4.50                         3.166667
# 163                        0.00                         3.000000
# 164                        0.00                         2.000000
# 165                        2.00                         2.500000
# 166                        0.00                         3.000000
# 167                        4.00                         5.250000
# 168                       -1.50                         2.650000
#
#      TaskEstimatedHoursPerStoryEstimate  \
# 0                              5.333333
# 1                              5.000000
# 2                              5.000000
# 3                              5.000000
# 4                              6.000000
# 5                              4.964286
# 6                              5.000000
# 7                              4.600000
# 8                              2.166667
# 9                              4.600000
# 10                             5.600000
# 11                             5.600000
# 12                             5.200000
# 13                             6.000000
# 14                             5.333333
# 15                             3.666667
# 16                             3.555556
# 17                             4.275862
# 18                             5.250000
# 19                             5.000000
# 20                             4.000000
# 21                             5.733333
# 22                             5.600000
# 23                             4.416667
# 24                             4.500000
# 25                             4.800000
# 26                             4.000000
# 27                             4.777778
# 28                             2.555556
# 29                             5.054945
# ..                                  ...
# 139                            7.181818
# 140                            8.000000
# 141                            6.076923
# 142                            5.428571
# 143                            6.666667
# 144                            7.333333
# 145                            5.423729
# 146                            5.666667
# 147                            4.750000
# 148                            6.750000
# 149                            5.739130
# 150                            6.615385
# 151                            7.000000
# 152                            6.444444
# 153                            6.800000
# 154                            6.727273
# 155                            6.000000
# 156                            5.666667
# 157                            6.000000
# 158                            5.636364
# 159                            6.740741
# 160                           10.000000
# 161                            1.300000
# 162                            3.250000
# 163                            3.000000
# 164                            2.000000
# 165                            2.166667
# 166                            3.000000
# 167                            4.250000
# 168                            2.800000
#
#      TaskActualHoursPerFunctionPrelimEstimate  \
# 0                                    3.000000
# 1                                    1.800000
# 2                                    2.400000
# 3                                    2.400000
# 4                                    0.600000
# 5                                    4.100000
# 6                                    3.800000
# 7                                    4.600000
# 8                                    2.800000
# 9                                    3.200000
# 10                                   4.200000
# 11                                   5.600000
# 12                                   5.200000
# 13                                   4.200000
# 14                                   6.000000
# 15                                   1.800000
# 16                                   3.000000
# 17                                   4.600000
# 18                                   6.600000
# 19                                   6.000000
# 20                                   1.000000
# 21                                   7.000000
# 22                                   5.600000
# 23                                   5.100000
# 24                                   5.200000
# 25                                   4.800000
# 26                                   4.250000
# 27                                   4.300000
# 28                                   2.200000
# 29                                   7.233333
# ..                                        ...
# 139                                  3.550000
# 140                                  5.000000
# 141                                  2.425000
# 142                                  4.250000
# 143                                  1.400000
# 144                                 13.600000
# 145                                  5.200000
# 146                                  0.566667
# 147                                  1.200000
# 148                                  4.700000
# 149                                  5.637500
# 150                                  7.400000
# 151                                  2.600000
# 152                                  2.066667
# 153                                  1.083333
# 154                                  7.700000
# 155                                  8.800000
# 156                                  3.500000
# 157                                  1.000000
# 158                                 10.050000
# 159                                  3.325000
# 160                                  0.500000
# 161                                  0.750000
# 162                                  5.700000
# 163                                  1.200000
# 164                                  0.800000
# 165                                  1.500000
# 166                                  1.200000
# 167                                  4.200000
# 168                                  2.650000
#
#      TaskEstimatedHoursPerFunctionPrelimEstimate
# 0                                       3.200000
# 1                                       2.500000
# 2                                       4.000000
# 3                                       4.000000
# 4                                       0.600000
# 5                                       4.633333
# 6                                       4.000000
# 7                                       4.600000
# 8                                       2.600000
# 9                                       4.600000
# 10                                      4.200000
# 11                                      5.600000
# 12                                      5.200000
# 13                                      3.600000
# 14                                      6.400000
# 15                                      2.200000
# 16                                      3.200000
# 17                                      6.200000
# 18                                      8.400000
# 19                                      6.000000
# 20                                      1.600000
# 21                                      7.166667
# 22                                      5.600000
# 23                                      5.300000
# 24                                      5.400000
# 25                                      4.800000
# 26                                      5.000000
# 27                                      4.300000
# 28                                      2.300000
# 29                                      7.666667
# ..                                           ...
# 139                                     3.950000
# 140                                     4.400000
# 141                                     3.950000
# 142                                     5.700000
# 143                                     2.000000
# 144                                    13.200000
# 145                                     5.333333
# 146                                     0.566667
# 147                                     3.800000
# 148                                     5.400000
# 149                                     6.600000
# 150                                     8.600000
# 151                                     2.800000
# 152                                     1.933333
# 153                                     1.133333
# 154                                     7.400000
# 155                                     8.400000
# 156                                     3.400000
# 157                                     1.200000
# 158                                     9.300000
# 159                                     4.550000
# 160                                     0.500000
# 161                                     1.300000
# 162                                     5.850000
# 163                                     1.200000
# 164                                     0.800000
# 165                                     1.300000
# 166                                     1.200000
# 167                                     3.400000
# 168                                     2.800000
#
# [169 rows x 12 columns]

# %%
def_df = defect_df[['ProjectName', 'IterationName', 'IterationStartDate']].sort_values(
    ['ProjectName','IterationStartDate'], ascending=False).reset_index()
rolling_count = def_df.groupby(['ProjectName', 'IterationName']).cumcount()
rolling_count.name = 'RollCount'
def_df = def_df.join(rolling_count)
last_5_df = def_df[def_df['RollCount'] < 5].drop(['index', 'IterationStartDate', 'RollCount'], axis=1)

defect_df = defect_df.merge(last_5_df, how='inner', on=['ProjectName', 'IterationName']).drop_duplicates()
if_def_report = defect_df[defect_df.DefectName != None].groupby(['ProjectName', 'DefectSeverity']).count().drop(
    ['IterationName', 'IterationStartDate', 'IterationEndDate'], axis=1
    )

def_df
# Out:
#     index             ProjectName             IterationName  \
# 0      43                 TSquare              Iteration 35
# 1      44                 TSquare              Iteration 34
# 2      46                 TSquare              Iteration 34
# 3      48                 TSquare              Iteration 17
# 4      50                 TSquare              Iteration 17
# 5      28                  Seurat  Iteration 2018.4 (2.2.4)
# 6      29                  Seurat  Iteration 2018.3 (2.2.3)
# 7      32                  Seurat  Iteration 2018.3 (2.2.3)
# 8      35                  Seurat  Iteration 2018.3 (2.2.3)
# 9      38                  Seurat  Iteration 2018.2 (2.2.2)
# 10     39                  Seurat  Iteration 2018.2 (2.2.2)
# 11     40                  Seurat  Iteration 2018.2 (2.2.2)
# 12     41                  Seurat  Iteration 2018.2 (2.2.2)
# 13     42                  Seurat  Iteration 2018.2 (2.2.2)
# 14      3  Market Data Connection         Iteration 2018.06
# 15      6  Market Data Connection         Iteration 2018.06
# 16      9  Market Data Connection         Iteration 2018.06
# 17     12  Market Data Connection         Iteration 2018.05
# 18     14  Market Data Connection         Iteration 2018.05
# 19     16  Market Data Connection         Iteration 2018.05
# 20     18  Market Data Connection         Iteration 2018.05
# 21     20  Market Data Connection         Iteration 2018.05
# 22     22  Market Data Connection         Iteration 2018.05
# 23     24  Market Data Connection         Iteration 2018.05
# 24     26  Market Data Connection         Iteration 2018.05
# 25      0    Compliance Workbench         Iteration 2016.99
# 26      1    Compliance Workbench         Iteration 2016.12
# 27      2    Compliance Workbench         Iteration 2016.11
#
#      IterationStartDate  RollCount
# 0   2018-03-05 05:00:00          0
# 1   2018-02-19 05:00:00          0
# 2   2018-02-19 05:00:00          1
# 3   2017-05-29 04:00:00          0
# 4   2017-05-29 04:00:00          1
# 5   2018-03-21 04:00:00          0
# 6   2018-03-07 05:00:00          0
# 7   2018-03-07 05:00:00          1
# 8   2018-03-07 05:00:00          2
# 9   2018-02-21 05:00:00          0
# 10  2018-02-21 05:00:00          1
# 11  2018-02-21 05:00:00          2
# 12  2018-02-21 05:00:00          3
# 13  2018-02-21 05:00:00          4
# 14  2018-03-14 04:00:00          0
# 15  2018-03-14 04:00:00          1
# 16  2018-03-14 04:00:00          2
# 17  2018-02-28 05:00:00          0
# 18  2018-02-28 05:00:00          1
# 19  2018-02-28 05:00:00          2
# 20  2018-02-28 05:00:00          3
# 21  2018-02-28 05:00:00          4
# 22  2018-02-28 05:00:00          5
# 23  2018-02-28 05:00:00          6
# 24  2018-02-28 05:00:00          7
# 25  2016-08-31 04:00:00          0
# 26  2016-07-06 04:00:00          0
# 27  2016-06-22 04:00:00          0

# %%
tts_final1 = pd.melt(
    tts_report_summary,
    id_vars = ['ProjectName'],
    value_vars = list(tts_report.columns).remove('ProjectName')
).set_index(['ProjectName', 'variable']).sort_index()

tts_final1.index.names = ['Project', 'Metric']

tts_final2 = pd.melt(
    tts_report_summary,
    id_vars = ['ProjectName'],
    value_vars = list(tts_report.columns).remove('ProjectName')
).set_index(['variable', 'ProjectName']).sort_index()

tts_final2.index.names = ['Metric', 'Project']

# %%
stf_final1 = pd.melt(
    stf_report,
    id_vars = ['ProjectName'],
    value_vars = list(stf_report.columns).remove('ProjectName')
).set_index(['ProjectName','variable']).sort_index()

stf_final1.index.names = ['Project', 'Metric']

stf_final2 = pd.melt(
    stf_report,
    id_vars = ['ProjectName'],
    value_vars = list(stf_report.columns).remove('ProjectName')
).set_index(['variable', 'ProjectName']).sort_index()

stf_final2.index.names = ['Metric', 'Project']

# %%
stf_final2
# Out:
#                                                                        value
# Metric                                      Project
# ActualVsEstimateTasksTotal                  Compliance Workbench   -5.951389
#                                             Market Data Connection -9.647030
#                                             Seurat                 -5.967391
#                                             TSquare                -0.611111
# StoryFunctionEstimateDiff                   Compliance Workbench    0.347222
#                                             Market Data Connection -2.737624
#                                             Seurat                 -5.369565
#                                             TSquare                 0.055556
# TaskActualHoursPerFunctionPrelimEstimate    Compliance Workbench    4.067824
#                                             Market Data Connection  4.859133
#                                             Seurat                  4.484964
#                                             TSquare                 2.055556
# TaskActualHoursPerStoryEstimate             Compliance Workbench    4.276956
#                                             Market Data Connection  4.927062
#                                             Seurat                  5.532771
#                                             TSquare                 3.590741
# TaskEstimatedHoursPerFunctionPrelimEstimate Compliance Workbench    4.625463
#                                             Market Data Connection  5.776271
#                                             Seurat                  4.985507
#                                             TSquare                 2.038889
# TaskEstimatedHoursPerStoryEstimate          Compliance Workbench    4.849363
#                                             Market Data Connection  5.638593
#                                             Seurat                  6.334758
#                                             TSquare                 3.529630

# %%
if_def_report
# Out:
#                                        DefectName
# ProjectName            DefectSeverity
# Compliance Workbench   0                        3
# Market Data Connection 1                        3
# Seurat                 0                        4
# TSquare                1                        1
#                        2                        2
